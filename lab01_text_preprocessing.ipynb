# %% [markdown]
# <a href="https://colab.research.google.com/github/cchan555/lis4693/blob/main/lab01_text_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install gensim
# !pip install matplotlib
# !pip install numpy
# !pip install nltk
# !pip install pandas
# !pip install pytesseract
# !pip install regex
# !pip install requests
# !pip install scikit-learn
# !pip install scipy
# !pip install seaborn
# !pip install spacy
# !pip install vadersentiment

import gensim
import matplotlib
import numpy
import nltk
import pandas
import pytesseract
import regex
import requests
import sklearn
import scipy
import seaborn
import spacy
from vaderSentiment import vaderSentiment
